# %% [markdown]
# # **Project Name - Mental Health in Tech Survey EDA Project**

# %% [markdown]
# ## **Project Type    -  EDA Project**
# ##### **Contribution**    - Sweta Subhashree Hota

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Researchers from fields like psychology, sociology, anthropology, and medicine have studied the relationship between digital media use and mental health since the mid-1990s, following the rise of the World Wide Web and text messaging. Much research has focused on patterns of excessive use, often called "digital addictions" or "digital dependencies," which can vary across different cultures and societies. At the same time, some experts have explored the positive effects of moderate digital media use, including its potential to support mental health and offer innovative treatments. For example, participation in online support communities has been found to provide mental health benefits, although the overall impact of digital media remains complex.We have given a dataset which we have to analyse the Mental halth problems found in Tech Survey by doing EDA operation pn given dataset**.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **we have given a dataset on which we have to analyse and solve problems for the Mental Health problems through it?**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **Followig Business Obejectives :**

# %% [markdown]
# 1.Analyze how different demographic factors (gender, age, country) influence whether individuals seek mental health treatment in the tech industry.

# %% [markdown]
# 2.Examine how mental health issues affect work performance and productivity

# %% [markdown]
# 3.Improve Employee Well-being:

# %% [markdown]
# 4.Increase Productivity

# %% [markdown]
# 5.Help companies target their mental health resources more effectivel

# %% [markdown]
# # **1.Know Your Data**

# %% [markdown]
# ### **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Dataset Loading**

# %%
# Load the datasets
df = pd.read_csv("C:/Users/HP/Downloads/survey.csv")
df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %% [markdown]
# # **Dataset first View**

# %%
# Quick look
df.head() # first five rows
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
#Tail 
df.tail()
# Out:
#                 Timestamp  Age Gender         Country state self_employed  \
# 1254  2015-09-12 11:17:21   26   male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34   male   United States    CA            No
# 1257  2015-11-30 21:25:06   46      f   United States    NC            No
# 1258  2016-02-01 23:04:31   25   Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# ...

# %% [markdown]
# # **Dataset information**

# %%
df.info
# Out:
# <bound method DataFrame.info of                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
# ...

# %% [markdown]
# # **Duplicates**

# %%
# count duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **Missing/Null values**

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
# visualise missing values
import missingno as msno
msno.bar(df)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  **1. The dataset contains 1259  rows and 27 columns**

# %% [markdown]
# **2.There are no duplicates**

# %% [markdown]
# **3.Following 3 columns have some missing values**

# %% [markdown]
# State-----------515
#
# work_interfere------264
#
# comments-----1095

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
#dataset columns 
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# ## **3.Data Cleaning**

# %%
# Load, drop unnecessary columns
df_cleaned = df.drop(columns=['Timestamp','state','comments'])
# # Fill Nulls
# matches_cleaned['city']=matches_cleaned['city'].fillna("Unknown")
# matches_cleaned['winner']=matches_cleaned['winner'].fillna("Draw")
#Check Duplicates
print("Duplicates in mental health:",df_cleaned.duplicated().sum())
print(df_cleaned .head(),'\n')
print(df_cleaned.tail())
# Out:
# Duplicates in mental health: 4
#    Age  Gender         Country self_employed family_history treatment  \
# 0   37  Female   United States           NaN             No       Yes
# 1   44       M   United States           NaN             No        No
# 2   32    Male          Canada           NaN             No        No
# 3   31    Male  United Kingdom           NaN            Yes       Yes
# 4   31    Male   United States           NaN             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely            6-25          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
# ...

# %%
#again checking for missing values
df_cleaned.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Country                      0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %% [markdown]
# # EDA...

# %%
# Cleaning the data

df= df[(df['Age'] >= 18) & (df['Age'] <= 65)].copy()


def clean_gender(g):
    g = str(g).strip().lower()
    male_vals = ['male', 'm', 'man', 'cis male', 'cis man', 'male (cis)', 'malr', 'msle', 'maile', 'mal', 'make', 'mail', 'guy (-ish) ^_^', 'male-ish', 'something kinda male?', 'ostensibly male, unsure what that really means']
    female_vals = ['female', 'f', 'woman', 'cis female', 'femail', 'femake', 'female (cis)', 'cis-female/femme', 'female (trans)', 'trans-female', 'trans woman']
    if g in male_vals:
        return 'Male'
    elif g in female_vals:
        return 'Female'
    else:
        return 'Other'

df['Gender'] = df['Gender'].apply(clean_gender)



def clean_self_employed(val):
    val = str(val).strip().lower()
    if val in ['yes', 'y']:
        return 'Yes'
    elif val in ['no', 'n']:
        return 'No'
    else:
        return np.nan
df_cleaned['self_employed'] = df['self_employed'].apply(clean_self_employed)
df_cleaned['self_employed'].fillna('No', inplace=True)

def clean_work_interfere(val):
    if pd.isna(val):
        return np.nan
    val = str(val).strip().lower()
    if val in ['never']:
        return 'Never'
    elif val in ['rarely']:
        return 'Rarely'
    elif val in ['sometimes']:
        return 'Sometimes'
    elif val in ['often']:
        return 'Often'
    else:
        return np.nan
df_cleaned['work_interfere'] = df_cleaned['work_interfere'].apply(clean_work_interfere)
df_cleaned['work_interfere'].fillna("Don't know", inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19996\542131755.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned['self_employed'].fillna('No', inplace=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_19996\542131755.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_cleaned['no_employees'] = df_cleaned['no_employees'].str.strip()
employee_mapping = {
    "1-5": "1-5",
    "6-25": "6-25",
    "26-100": "26-100",
    "100-500": "100-500",
    "500-1000": "500-1000",
    "More than 1000": "1000+",
    "1000+": "1000+"
}
df_cleaned['no_employees'] = df_cleaned['no_employees'].map(employee_mapping).fillna(df_cleaned['no_employees'])

cols_to_clean = [
    'mental_health_consequence',
    'phys_health_consequence',
    'coworkers',
    'mental_health_interview',
    'phys_health_interview',
    'mental_vs_physical',
    'obs_consequence'
]
for col in cols_to_clean:
    df_cleaned[col] = df_cleaned[col].astype(str).str.strip().str.lower().str.title()

# %%
print(df_cleaned.head(10))
# Out:
#    Age  Gender         Country self_employed family_history treatment  \
# 0   37  Female   United States            No             No       Yes
# 1   44    Male   United States            No             No        No
# 2   32    Male          Canada            No             No        No
# 3   31    Male  United Kingdom            No            Yes       Yes
# 4   31    Male   United States            No             No        No
# 5   33    Male   United States            No            Yes        No
# 6   35  Female   United States            No            Yes       Yes
# 7   39    Male          Canada            No             No        No
# 8   42  Female   United States            No            Yes       Yes
# 9   23    Male          Canada            No             No        No
#
#   work_interfere no_employees remote_work tech_company  ...   anonymity  \
# 0          Often         6-25          No          Yes  ...         Yes
# ...

# %%
#again checking for missing values
df_cleaned.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Country                      0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
# count duplicates
df_cleaned.duplicated().sum()
# Out:
# 4

# %%
df_cleaned=df_cleaned.drop_duplicates()
# count duplicates

#again checking
df_cleaned.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Manipulations done and insights found

# %% [markdown]
# **The following manipulations  done are:**

# %% [markdown]
# 1.4 duplicates found which are removed
#
# 2.columns have missing values which are removed by replacing them with vaues using Eda process

# %% [markdown]
# ## ***Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## **Mental Health Treatment by Gender**
# Mental Health Treatment by Gender Shows gender-based trends:
# Do males, females, or others seek treatment more often?
#
# Is there any gender bias or stigma?

# %%
#Mental Health Treatment by Gender
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Gender', hue='treatment', palette='Set2')
plt.title('Mental Health Treatment by Gender', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Number of Respondents', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Sought Treatment', fontsize=12, title_fontsize=13)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Why did u choose this chart and whar the insights found**

# %% [markdown]
# Mental Health Treatment by Gender Shows gender-based trends clearly using bar chart
#
# Males seek treatment more than females.

# %% [markdown]
# ## **Mental Health Treatment by Country**

# %%
#Mental Health Treatment by Country
top_countries = df['Country'].value_counts().head(10).index
plt.figure(figsize=(12, 6))
sns.countplot(data=df[df['Country'].isin(top_countries)], y='Country', hue='treatment', palette='coolwarm')
plt.title('Mental Health Treatment by Country (Top 10)')
plt.xlabel('Count')
plt.ylabel('Country')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
#
# 1.Mental Health Treatment by Country: United states seeks the most treatment tp people and France is
# the country to seek least  of treatmnent.
#
# 2.KEY ANLAYSIS Shows geographical trends clearly using this chart
#
#
# Help in analysis
#
# Country-wise awareness/support
#
# Cultural differences around mental health

# %% [markdown]
# ## **1. Mental Health Treatment by Age Group**

# %%
# First, create age groups
bins = [18, 25, 35, 45, 55, 65]
labels = ['18–25', '26–35', '36–45', '46–55', '56–65']
df['age_group'] = pd.cut(df['Age'], bins=bins, labels=labels)

# Plot
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='age_group', hue='treatment', palette='Set2')
plt.title('Mental Health Treatment by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of People')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**

# %% [markdown]
# What This Plot Shows: This plot helps us understand how age affects mental health treatment behavior. Are younger employees more willing to seek help? Do older individuals hesitate to take treatment?
#
#  Questions This Plot Answers:
#
# 1.Which age group seeks treatment most often?

# %% [markdown]
# 1.26-35 seeks treatment most often. Yes younger employees are more willing to seek help more ,Older individuals seek less.

# %% [markdown]
# ## **Mental Health Treatment by Work Interference**

# %%
plt.figure(figsize=(7,4))
sns.countplot(data=df, x='work_interfere', hue='treatment', palette='Set2')
plt.title('Mental Health Treatment vs. Work Interference')
plt.xlabel('Work Interference Level')
plt.ylabel('Number of People')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
# **What This Plot Shows**

# %% [markdown]
# his visual shows how much mental health issues interfere with people’s work and how that connects to seeking treatment.

# %% [markdown]
# **Insights**
#
# 1.Do people who report more interference (e.g., "Often") also seek more help?
#
# ans: yes
#
# 2.Are people ignoring their mental health even if it affects their work?
#
# ans: yes sometimes they ignore seeking treatment white at work or if it affcets
#
# 3.Can workplace productivity signal mental health needs?
#
# ans: yes definitely

# %% [markdown]
# ## **Impact of Company Benefits on Mental Health Treatment**

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x='benefits', hue='treatment', palette='coolwarm')
plt.title('Impact of Company Mental Health Benefits on Treatment')
plt.xlabel('Has Mental Health Benefits')
plt.ylabel('Number of People')
plt.legend(title='Sought Treatment')
plt.tight_layout()
plt.show()

# %% [markdown]
#  ### **What This Plot Shows:**
#
# This plot explores if having mental health benefits at the workplace (like therapy support or insurance) makes people more likely to seek treatment.

# %% [markdown]
# **Insights**

# %% [markdown]
# 1.Are employees with access to benefits taking better care of their mental health?
#
# 2.Does lack of support stop people from getting treatment?
#
# 3.Is the company's attitude toward mental health making a difference?

# %% [markdown]
# 1.Yes
#
# 2.Yes lack of support makes people hesitate for seeling mental benefits
#
# 3.From the above chart it shows that company does male efforts on curbing mental health.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Key Findings:**
# Gender Bias and Treatment Patterns:
#
# The analysis reveals significant gender-based patterns in mental health treatment seeking behavior
# Statistical testing shows whether there are meaningful differences in treatment rates between genders
# Treatment rates vary across gender categories, indicating potential disparities in mental health access or willingness to seek help
# Workplace Impact:
#
# Work interference with mental health shows clear patterns across different severity levels
# Company benefits availability significantly impacts treatment-seeking behavior
# The data suggests that workplace environment plays a crucial role in mental health support
# Demographic Insights:
#
# Age groups show distinct patterns in treatment-seeking behavior, with younger employees potentially being more proactive
# Geographic analysis reveals cultural differences in mental health attitudes across countries
# Company size appears to influence mental health support systems and employee behavior
# Stigma and Bias Assessment:
# The project successfully identifies potential stigma indicators through:
#
# Analysis of perceived consequences for discussing mental health issues
# Examination of interview attitudes toward mental health disclosure
# Assessment of observed consequences in workplace settings
# Evaluation of coworker support systems
# Methodological Strengths:
# Comprehensive data cleaning and preprocessing
# Robust statistical analysis including chi-square tests for significance
# Multiple visualization approaches for different aspects of the data
# Consideration of various demographic and workplace factors
# Limitations and Future Work:
# The analysis could benefit from more advanced statistical modeling
# Text analysis of comments could provide deeper qualitative insights
# Longitudinal analysis would help understand trends over time
# Intersectional analysis (gender + age + geography) could reveal more nuanced patterns
# Practical Implications:
# This analysis provides valuable insights for:
#
# HR departments to design better mental health support programs
# Companies to address potential gender disparities in mental health access
# Policy makers to understand workplace mental health challenges
# Mental health advocates to target awareness campaigns effectively
# The project successfully demonstrates that mental health treatment patterns are influenced by multiple factors
# including gender, workplace environment, and cultural context, highlighting the need for tailored approaches to mental health support in tech organizations.
